# %%
import pandas as pd
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# %% [markdown]
# Columna Age tiene números escritos en letras tendríamos que convertir en INT
# Attrition Son no y si (tipeamos para saber)
# BusinessTravel tiene campos Vacios tendremos que limpiar los strings
# DailyRate convertir a float y quitar simbolo y ver Nan
# Department son string tenemos que mirar los Vacios
# DistanceFromHome Vemos númeron negativos que tendremos que revisar y los dejamos en INT
# Education INT en principio sin cambios
# EducationField String algunos vacios
# EmployeeCount en teoria sirve para contar empleado (puede ser prescindible)
# EmployeeNumber contiene Nan es numero float que quizas deberíamos  no se deberían repetir
# EnvironmentSatisfaction tenemos numeros superiors a la satisfaccion (numeros del 1 al 4) Por lo que vemos tenemos que quitar el segundo numero
# Gender 0 = h 1 = m
# HourlyRate debería ser numeros pero hay algunos que son texto (es posible que tengamos que cambiarlo por 0)
# JobInvolvement todos numeros
# JobLevel todo números del 1-5
# JobRole Mayúsculas y minúsculas todos tienen datos
# JobSatisfaction numeros del 1-4
# MaritalStatus  hay blancos
# MonthlyIncome tenemos nan
# MonthlyRate numeros
# NumCompaniesWorked número de companías en la que ha trabajado el empleado, número INT
# Over18 Comprobar los datos vacios con la edad
# OverTime Hay algunas Vacias
# PercentSalaryHike Numero entero (posible porcentaje)
# PerformanceRating Hay nan están en INT
# RelationshipSatisfaction numeros de 1-4 comparar con EnvironmentSatisfaction y JobSatisfaction
# StandardHours o nan o 80 no sabemos qué tipo de jornada 😱😱😱😱😱😱😱😱😱
# StockOptionLevel Numeros de 0 a 3
# TotalWorkingYears  nan hay numeros
# TrainingTimesLastYear numeros INT
# WorkLifeBalance numero INT nan 0-4
# YearsAtCompany numero
# YearsInCurrentRole Hay muchos Nan y algún número
# YearsSinceLastPromotion Hay numeros
# YearsWithCurrManager Hay numeros
# SameAsMonthlyIncome nan hay num
# DateBirth todas fechas sin vacios podemos comprabar la columna age
# Salary revisar TODO huele mal ....
# RoleDepartament muchas vacias Tendríamos que partila
#
# NumberChildren: Número de hijos de los empleados. no hay nada (Borrar)
#
#
# RemoteWork: Si el empleado puede teletrabajar o no. TRUE/False  cambiar YES/NO  y número 0 -1

# %%
df = pd.read_csv('datos/datos_empresa.csv', index_col=0)
df
# Out:
#      Age Attrition BusinessTravel DailyRate                Department  \
# 0     51        No            NaN    684,0$                       NaN
# 1     52        No            NaN    699,0$                       NaN
# 2     42        No  travel_rarely    532,0$   Research & Development
# 3     47        No  travel_rarely    359,0$                       NaN
# 4     46        No            NaN   1319,0$                       NaN
# ...   ..       ...            ...       ...                       ...
# 1609  36       Yes  travel_rarely    530,0$                       NaN
# 1610  45        No     non-travel    805,0$                       NaN
# 1611  39        No  travel_rarely    903,0$                       NaN
# 1612  36        No     non-travel   1229,0$                       NaN
# 1613  46        No            NaN    566,0$                       NaN
#
#       DistanceFromHome  Education    EducationField  employeecount  \
# ...

# %%
df.head(1)
# Out:
#   Age Attrition BusinessTravel DailyRate Department  DistanceFromHome  \
# 0  51        No            NaN    684,0$        NaN                 6
#
#    Education EducationField  employeecount employeenumber  \
# 0          3            NaN              1          162,0
#
#    EnvironmentSatisfaction  Gender HourlyRate  JobInvolvement  JobLevel  \
# 0                        1       0         51               3         5
#
#                JobRole  JobSatisfaction MaritalStatus MonthlyIncome  \
# 0   resEArch DIREcToR                 3           NaN       19537,0
#
#    MonthlyRate  NUMCOMPANIESWORKED Over18 OverTime  PercentSalaryHike  \
# 0         6462                   7      Y       No                 13
#
#   PerformanceRating  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0               3,0                         3           NaN                 0
#
#   TOTALWORKINGYEARS  TrainingTimesLastYear WORKLIFEBALANCE  YearsAtCompany  \
# ...

# %%
df.shape
# Out:
# (1614, 41)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1614 entries, 0 to 1613
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1614 non-null   object
#  1   Attrition                 1614 non-null   object
#  2   BusinessTravel            842 non-null    object
#  3   DailyRate                 1614 non-null   object
#  4   Department                302 non-null    object
#  5   DistanceFromHome          1614 non-null   int64
#  6   Education                 1614 non-null   int64
#  7   EducationField            869 non-null    object
#  8   employeecount             1614 non-null   int64
#  9   employeenumber            1183 non-null   object
#  10  EnvironmentSatisfaction   1614 non-null   int64
#  11  Gender                    1614 non-null   int64
#  12  HourlyRate                1614 non-null   object
#  13  JobInvolvement            1614 non-null   int64
# ...

# %%
df.describe(include='O').T
# Out:
#                     count unique                       top  freq
# Age                  1614     54                        35    84
# Attrition            1614      2                        No  1355
# BusinessTravel        842      3             travel_rarely   586
# DailyRate            1614    849                      nan$   124
# Department            302      3   Research & Development    196
# EducationField        869      6             Life Sciences   349
# employeenumber       1183   1079                     482,0     2
# HourlyRate           1614     72             Not Available    84
# JobRole              1614   1579                  mANager      4
# MaritalStatus         963      5                   Married   404
# MonthlyIncome         771    668                    6347,0     4
# Over18                713      1                         Y   713
# OverTime              938      2                        No   682
# ...

# %%
df.describe().T
# Out:
#                            count          mean          std     min     25%  \
# DistanceFromHome          1614.0      4.527261    14.591913   -49.0     2.0
# Education                 1614.0      2.925031     1.022357     1.0     2.0
# employeecount             1614.0      1.000000     0.000000     1.0     1.0
# EnvironmentSatisfaction   1614.0      4.294919     6.993559     1.0     2.0
# Gender                    1614.0      0.398389     0.489718     0.0     0.0
# JobInvolvement            1614.0      2.739777     0.711567     1.0     2.0
# JobLevel                  1614.0      2.068154     1.101344     1.0     1.0
# JobSatisfaction           1614.0      2.738538     1.106163     1.0     2.0
# MonthlyRate               1614.0  14284.495663  7110.414585  2094.0  8001.0
# NUMCOMPANIESWORKED        1614.0      2.673482     2.506152     0.0     1.0
# PercentSalaryHike         1614.0     15.165428     3.648610    11.0    12.0
# ...

# %%
df.isna().sum()
# Out:
# Age                            0
# Attrition                      0
# BusinessTravel               772
# DailyRate                      0
# Department                  1312
# DistanceFromHome               0
# Education                      0
# EducationField               745
# employeecount                  0
# employeenumber               431
# EnvironmentSatisfaction        0
# Gender                         0
# HourlyRate                     0
# JobInvolvement                 0
# JobLevel                       0
# JobRole                        0
# JobSatisfaction                0
# MaritalStatus                651
# MonthlyIncome                843
# MonthlyRate                    0
# NUMCOMPANIESWORKED             0
# Over18                       901
# OverTime                     676
# PercentSalaryHike              0
# PerformanceRating            195
# RelationshipSatisfaction       0
# StandardHours               1195
# StockOptionLevel               0
# ...

# %%
df.isna().sum() / df.shape[0] * 100
# Out:
# Age                           0.000000
# Attrition                     0.000000
# BusinessTravel               47.831475
# DailyRate                     0.000000
# Department                   81.288724
# DistanceFromHome              0.000000
# Education                     0.000000
# EducationField               46.158612
# employeecount                 0.000000
# employeenumber               26.703841
# EnvironmentSatisfaction       0.000000
# Gender                        0.000000
# HourlyRate                    0.000000
# JobInvolvement                0.000000
# JobLevel                      0.000000
# JobRole                       0.000000
# JobSatisfaction               0.000000
# MaritalStatus                40.334572
# MonthlyIncome                52.230483
# MonthlyRate                   0.000000
# NUMCOMPANIESWORKED            0.000000
# Over18                       55.824040
# OverTime                     41.883519
# PercentSalaryHike             0.000000
# ...

# %%
# df.duplicated(subset='id').sum() para ver duplicados de una columna
# Out:
# 0
